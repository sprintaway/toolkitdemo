# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from pipelines import NaiveBayesPipeline
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection


df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
fs = FeatureSelector(X_train, y_train, task_type='classification')
fs.run_selection()

# %%
results_table = fs.get_results_table()
print(results_table)

# %%
count_table = fs.get_count()
print("Feature selection counts:")
print(count_table)

# %%
all_selected = fs.all_features_selected()
print("\nFeatures selected by all methods:", all_selected)

# %%
fs.feature_plot(all_selected)

# %%
selected_by_2 = fs.selected_by_at_least(2)
print("\nFeatures selected by at least 2 methods:", selected_by_2)

fs.feature_plot(selected_by_2)

# %%
od = OutlierDetector(X_train, y_train)
outliers = od.run_selection()

# %%
nb_pipeline = NaiveBayesPipeline(X_train, y_train, task_type='classification')
nb_pipeline
nb_pipeline.fit()

y_pred = nb_pipeline.predict(X_test)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from pipelines import NaiveBayesPipeline
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection


df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

nb_pipeline = NaiveBayesPipeline(X_train, y_train, task_type='classification')
nb_pipeline

# %%
accuracy = np.mean(y_pred == y_test)
print(f'Test Accuracy: {accuracy:.4f}')

# %%
df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from pipelinesV2 import NBPipeline
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection


df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

nb_pipeline = NBPipeline(task_type='classification')
nb_pipeline

# %%
nb_pipeline.fit(X_train, y_train)
y_pred = nb_pipeline.predict(X_test)

# %%
print(y_pred)

# %%
accuracy = np.mean(y_pred == y_test)
print(f'Test Accuracy: {accuracy:.4f}')

# %%
nb_pipeline.steps[-1]

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'imputer__datasets': [3, 4],
    'imputer__iterations': [3],
    'classifier__gnb__var_smoothing': [1e-9],
}

grid_search = GridSearchCV(nb_pipeline, param_grid, cv=5)
grid_search.fit(X_train, y_train)

print("Best Score: ", grid_search.best_score_)
print("Best Params: ", grid_search.best_params_)

best_model = grid_search.best_estimator_

# %%
from pipelinesV2 import GLMPipeline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

glm_pipeline = GLMPipeline(task_type='classification')
glm_pipeline

# %%
from pipelinesV2 import GLMPipeline, NBPipeline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print("NA values in y_train:", y_train.isna().sum())

# Create and fit the pipeline (you can choose either NBPipeline or GLMPipeline)
pipeline = NBPipeline(task_type='classification')  # or GLMPipeline()
pipeline.fit(X_train, y_train)

# Check encoded y_train
# Check for missing values in encoded y_train
encoded_y_train = pipeline.named_steps['save_encoded_y'].encoded_y
missing_values = np.isnan(encoded_y_train).sum()
print("Number of missing values in encoded y_train:", missing_values)

# Check unique values in encoded y_train
unique_values = np.unique(encoded_y_train)
print("Unique values in encoded y_train:", unique_values)

# Check if encoding is correct (assuming binary classification)
if len(unique_values) == 2 and set(unique_values) == {0, 1}:
    print("y_train seems to be correctly encoded for binary classification")
else:
    print("Warning: y_train encoding might not be correct for binary classification")

# Print a sample of encoded y_train
print("Sample of encoded y_train:")
print(encoded_y_train[:10])

# If you want to see the original labels, you can inverse transform
if pipeline.task_type == 'classification' and pipeline.label_encoder is not None:
    original_labels = pipeline.label_encoder.inverse_transform(encoded_y_train)
    print("\nSample of original labels:")
    print(original_labels[:10])

# Check preprocessed X_train
preprocessed_X_train = pipeline.get_preprocessed_data(X_train)
print("Shape of preprocessed X_train:", preprocessed_X_train.shape)
print("Sample of preprocessed X_train:")
print(preprocessed_X_train[:5])

# Check preprocessed X_test
preprocessed_X_test = pipeline.get_preprocessed_data(X_test)
print("Shape of preprocessed X_test:", preprocessed_X_test.shape)
print("Sample of preprocessed X_test:")
print(preprocessed_X_test[:5])

# If you want to make predictions
y_pred = pipeline.predict(X_test)
print("Shape of predictions:", y_pred.shape)
print("Sample of predictions:")
print(y_pred[:5])

# %%
from pipelinesV2 import GLMPipeline, NBPipeline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print("NA values in y_train:", y_train.isna().sum())

# Create and fit the pipeline (you can choose either NBPipeline or GLMPipeline)
pipeline = NBPipeline(task_type='classification')  # or GLMPipeline()
pipeline.fit(X_train, y_train)

# Get the preprocessed X_train
preprocessed_X_train = pipeline.named_steps['save_preprocessed_x'].preprocessed_X

# Get the encoded y_train
encoded_y_train = pipeline.named_steps['save_encoded_y'].encoded_y

# Now preprocessed_X_train and encoded_y_train should have the same number of rows
print("Shape of preprocessed_X_train:", preprocessed_X_train.shape)
print("Shape of encoded_y_train:", encoded_y_train.shape)

# %%
print(preprocessed_X_train)
print(encoded_y_train)

# %%
y_pred = pipeline.predict(X_test)
accuracy = np.mean(y_pred == y_test)
print(f'Test Accuracy: {accuracy:.4f}')

# %%
# Test if separation of pipeline would still work? (But here I don't have y_train_processed since I'm not using a custom pipeline?)

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline = NBPipeline(task_type='classification')

pipeline_steps = pipeline.steps[:-1]

new_pipeline = Pipeline(pipeline_steps)

X_train_processed = new_pipeline.fit_transform(X_train, y_train)

# %%
y_train_processed = new_pipeline.named_steps['save_encoded_y'].encoded_y

# %%
print(X_train_processed.shape)
print(X_train_processed)
print(y_train_processed)
print(y_train_processed.shape)
print(y_train_processed.unique())

# %%
gnb = GaussianNB()

gnb.fit(X_train_processed, y_train_processed)
X_test_processed = new_pipeline.transform(X_test)  

y_pred = gnb.predict(X_test_processed)

# %%
from pipelinesV2 import GLMPipeline, NBPipeline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print("NA values in y_train:", y_train.isna().sum())

# Create and fit the pipeline (you can choose either NBPipeline or GLMPipeline)
glm_pipeline = GLMPipeline(task_type='classification')  # or GLMPipeline()
glm_pipeline.fit(X_train, y_train)

# Get the preprocessed X_train
preprocessed_X_train = glm_pipeline.named_steps['save_preprocessed_x'].preprocessed_X

# Get the encoded y_train
encoded_y_train = glm_pipeline.named_steps['save_encoded_y'].encoded_y

# Now preprocessed_X_train and encoded_y_train should have the same number of rows
print("Shape of preprocessed_X_train:", preprocessed_X_train.shape)
print("Shape of encoded_y_train:", encoded_y_train.shape)

# %%
print(preprocessed_X_train)
print(encoded_y_train)

# %%
y_pred = glm_pipeline.predict(X_test)
accuracy = np.mean(y_pred == y_test)
print(f'Test Accuracy: {accuracy:.4f}')

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'classifier__C': [0.1, 0.5],
}

grid_search = GridSearchCV(pipeline, param_grid)
grid_search.fit(preprocessed_X_train, encoded_y_train)

print("Best Score: ", grid_search.best_score_)
print("Best Params: ", grid_search.best_params_)

best_model = grid_search.best_estimator_

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'mice_imputer__datasets': [3, 4],
}

grid_search = GridSearchCV(pipeline, param_grid)
grid_search.fit(X_train, y_train)

print("Best Score: ", grid_search.best_score_)
print("Best Params: ", grid_search.best_params_)

best_model = grid_search.best_estimator_

# %%
glm_pipeline[-1]

# %%
glm_pipeline[0:3]

# %%
X_train_processed = glm_pipeline[0].fit_transform(X_train)

# %%
len(glm_pipeline)

# %%
glm_pipeline.fit(X_train, y_train)
y_pred = glm_pipeline.predict(X_test)

# %%
accuracy = np.mean(y_pred == y_test)
print(f'Test Accuracy: {accuracy:.4f}')

# %%
# This part onwards is using pipelinesV3 (not pipelinesV2)!!!!!!!!!!!!

from pipelinesV3 import GLMPipeline, NBPipeline, CustomPipeline
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline = NBPipeline(task_type='classification')

print("First step:", pipeline[0])
print("First two steps:")
print(pipeline[0:2])
print("All steps except the last:")
print(pipeline[:-1])
# Out:
# First step: RemoveMissingYValues()
# First two steps:
# NBPipeline(steps=[('remove_missing_y', RemoveMissingYValues()),
#                   ('save_missing_y_mask', SaveMissingYMask()),
#                   ('save_encoded_y', SaveEncodedY()),
#                   ('converter', ColumnTypeConverter()),
#                   ('mice_imputer', MICEImputer()),
#                   ('preprocessor',
#                    CustomColumnTransformer(transformers=[('num',
#                                                           Pipeline(steps=[('passthrough',
#                                                                            'passthrough')]),
#                                                           <function NBPipeline.__init__.<local...
#                                                                            OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                           unknown_value=-1))]),
#                                                           <function NBPipeline.__init__.<locals>.<lambda> at 0x0000027AED034A60>)])),
#                   ('save_preprocessed_x', SavePreprocessedX()),
#                   ('to_array', DataFrameToArrayTransformer()),
#                   ('classifier', GaussianNB())],
#            task_type=[('remove_missing_y', RemoveMissingYValues()),
#                       ('save_missing_y_mask', SaveMissingYMask())])
# All steps except the last:
# NBPipeline(steps=[('remove_missing_y', RemoveMissingYValues()),
#                   ('save_missing_y_mask', SaveMissingYMask()),
#                   ('save_encoded_y', SaveEncodedY()),
#                   ('converter', ColumnTypeConverter()),
#                   ('mice_imputer', MICEImputer()),
#                   ('preprocessor',
#                    CustomColumnTransformer(transformers=[('num',
#                                                           Pipeline(steps=[('passthrough',
#                                                                            'passthrough')]),
#                                                           <function NBPipeline.__init__.<local...
#                                                                                'passthrough')]),
#                                                               <function NBPipeline.__init__.<locals>.<lambda> at 0x0000027AEA310EE0>),
#                                                              ('cat',
#                                                               Pipeline(steps=[('ordinal',
#                                                                                OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                               unknown_value=-1))]),
#                                                               <function NBPipeline.__init__.<locals>.<lambda> at 0x0000027AE549DD80>)])),
#                       ('save_preprocessed_x', SavePreprocessedX()),
#                       ('to_array', DataFrameToArrayTransformer())])

# %%
pipeline_steps = pipeline.steps[:-1]  
new_pipeline = Pipeline(pipeline_steps)  

X_train_processed = new_pipeline.fit_transform(X_train, y_train)

# %%
pipeline.preprocessor
# Out:
# CustomPipeline(steps=[('remove_missing_y', RemoveMissingYValues()),
#                       ('save_missing_y_mask', SaveMissingYMask()),
#                       ('save_encoded_y', SaveEncodedY()),
#                       ('converter', ColumnTypeConverter()),
#                       ('mice_imputer', MICEImputer()),
#                       ('preprocessor',
#                        CustomColumnTransformer(transformers=[('num',
#                                                               Pipeline(steps=[('passthrough',
#                                                                                'passthrough')]),
#                                                               <function NBPipeline.__init__.<locals>.<lambda> at 0x0000027AEA310EE0>),
#                                                              ('cat',
#                                                               Pipeline(steps=[('ordinal',
#                                                                                OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                               unknown_value=-1))]),
#                                                               <function NBPipeline.__init__.<locals>.<lambda> at 0x0000027AE549DD80>)])),
#                       ('save_preprocessed_x', SavePreprocessedX()),
#                       ('to_array', DataFrameToArrayTransformer())])

# %%
pipeline.classifier
# Out:
# GaussianNB()

# %%
print(pipeline.classifier)
# Out:
# GaussianNB()

# %%
pipeline_steps = pipeline.steps[:-1]
new_pipeline = CustomPipeline(pipeline_steps)

X_train_processed, y_train_processed = new_pipeline.fit_transform(X_train, y_train)

# %%
X_train_processed = pipeline.fit_transform(X_train, y_train)

# %%
pipeline.steps[:-1]

# %%
print(X_train_processed.shape)
print(X_train_processed)
print(y_train_processed)
print(y_train_processed.shape)
print(y_train_processed.unique())

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

gnb.fit(X_train_processed, y_train_processed)

# %%
X_test_processed, _ = new_pipeline.transform(X_test)  

y_pred = gnb.predict(X_test_processed)


#### NOTE: Issue here is that the y_pred here is the encoded output with only 0 or 1. But y_test is 'yes', 'no' and NA values. So not possible to compare accuracy unless we
# 1. inverse_transform back y_pred
# 2. create a mask to remove NA values in both y_pred and y_test

# We also cannot override the predict method of GNB to make it return the unencoded y_pred.

# %%
y_pred = pipeline.inverse_transform(y_pred)

# %%
print(y_pred)

# %%
y_pred_original = pipeline.named_steps['save_encoded_y'].inverse_transform(y_pred)


mask = ~pd.isnull(y_test)
y_test_clean = y_test[mask]
y_pred_clean = y_pred_original[mask]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test_clean, y_pred_clean)
print(f'Accuracy: {accuracy}')

report = classification_report(y_test_clean, y_pred_clean)
print(f'Classification Report:\n{report}')

conf_matrix = confusion_matrix(y_test_clean, y_pred_clean)
print(f'Confusion Matrix:\n{conf_matrix}')

# %%
from pipelinesV3 import GLMPipeline, NBPipeline, CustomPipeline
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline = NBPipeline(task_type='classification')
pipeline.fit(X_train, y_train)

# %%
pipeline[-1]

# %%
y_pred = pipeline.predict(X_test)
print(y_pred)

# %%
print(y_pred)

# %%
accuracy = np.mean(y_pred == y_test)
print(f'Test Accuracy: {accuracy:.4f}')

# %%
print(y_pred)
print(y_test)

# %%
from pipelinesV3 import GLMPipeline, NBPipeline, CustomPipeline
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline = GLMPipeline(task_type='classification')
pipeline.fit(X_train, y_train)

# %%
y_pred = pipeline.predict(X_test)

# %%
accuracy = np.mean(y_pred == y_test)
print(f'Test Accuracy: {accuracy:.4f}')

# %%
# This part onwards is using pipelinesV3 (not pipelinesV2)!!!!!!!!!!!!

from pipelinesV3 import GLMPipeline, NBPipeline, CustomPipeline
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline = GLMPipeline(task_type='classification')

print("First step:", pipeline[0])
print("First two steps:")
print(pipeline[0:2])
print("All steps except the last:")
print(pipeline[:-1])

# %%
y_train_processed = new_pipeline['save_encoded_y'].encoded_y

# %%
print(y_train_processed)

# %%
pipeline[0]

# %%
pipeline[0:2]

# %%
from pipelinesV3 import GLMPipeline, NBPipeline, CustomPipeline
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import miceforest as mf
from feature_selection import FeatureSelector
import feature_selection
from outlier_detection import OutlierDetector
import outlier_detection
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from scipy.stats import uniform, randint

df = pd.read_csv('weatherAUStest.csv')
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

pipeline = NBPipeline(task_type='classification')

# %%
from pipelinesV3 import PreprocessedSplitter
from sklearn.model_selection import GridSearchCV, KFold

base_cv = KFold(n_splits=5, shuffle=True, random_state=42)
cv = PreprocessedSplitter(base_cv, pipeline)

param_grid = {'classifier__var_smoothing': [1e-9, 1e-10]}

# %%
grid_search = GridSearchCV(
    pipeline,
    param_grid=param_grid,
    cv=cv,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2,
)

# %%
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)

# %%
X_transformed, y_transformed = pipeline.fit_transform(X_train, y_train)
print("Transformed y:", y_transformed)
print("Transformed y type:", type(y_transformed))
print("Transformed y dtype:", y_transformed.dtype)

# %%
param_distributions = {
    'mice_imputer__datasets': randint(2, 5),
    'mice_imputer__iterations': randint(2, 5),
    'preprocessor__num__scaler__with_mean': [True, False],
    'preprocessor__num__scaler__with_std': [True, False],
    'classifier__var_smoothing': uniform(1e-10, 1e-8)
}

random_search = RandomizedSearchCV(
    pipeline,
    param_distributions=param_distributions,
    n_iter=10,  
    cv=5,  
    scoring='accuracy',  
    n_jobs=-1,  
    verbose=2,
    random_state=42
)

# %%
random_search.fit(X, y)
